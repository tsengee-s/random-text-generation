# %% [markdown]
# ## Author: Tsengee (Tsengelmaa) Sundui

# %% [markdown]
# ## 1. Clean input text by removing all punctuation, except periods. Convert everything to lower case.
# ### (Done seperately)

# %%
data_file_location = 'C:/Users/sundu/OneDrive - The University of Chicago/Documents/Winter 2023/walden_clean.txt'

# %% [markdown]
# ## 2. For each sentence, create pairs of consecutive words

# %%
import re
with open(data_file_location, 'r', encoding='utf-8') as f:
    text = f.read()
    text = text.replace(".", " PERIOD ")
    sentences = text.split(" PERIOD ")
    sentences = [sentence + " PERIOD" for sentence in sentences]
    sentences = sentences[4:]
    word_pairs = []
    for sentence in sentences:
        words = sentence.split()
        for i in range(0, len(words) - 1):
            word_pairs.append((words[i], words[i+1]))

print(word_pairs[:20])
# Out:
# [('i', 'lived'), ('lived', 'there'), ('there', 'two'), ('two', 'years'), ('years', 'and'), ('and', 'two'), ('two', 'months'), ('months', 'PERIOD'), ('at', 'present'), ('present', 'i'), ('i', 'am'), ('am', 'a'), ('a', 'sojourner'), ('sojourner', 'in'), ('in', 'civilized'), ('civilized', 'life'), ('life', 'again'), ('again', 'PERIOD'), ('i', 'should'), ('should', 'not')]

# %% [markdown]
# ## 3. Count how often each pair of words occurs in the input text and record it for later retrieval.

# %%
from collections import defaultdict

def transition_matrix(word_pairs):
    # Create a dictionary to hold counts of word pairs
    counts = defaultdict(dict)

    # Count occurrences of word pairs
    for w1, w2 in word_pairs:
        if w2 not in counts[w1]:
            counts[w1][w2] = 0
        if w1 not in counts[w2]:
            counts[w2][w1] = 0
        counts[w1][w2] += 1
        counts[w2][w1] += 1

    return counts

#Testing the function
trans = transition_matrix(word_pairs)
print(trans['whom'])
# Out:
# {'else': 1, 'i': 9, 'him': 1, 'it': 5, 'race': 1, 'we': 5, 'with': 6, 'he': 3, 'people': 1, 'they': 3, 'booby': 1, 'to': 5, 'heroes': 1, 'as': 1, 'man': 2, 'of': 3, 'by': 1, 'workman': 1, 'friend': 1, 'having': 1, 'pauper': 1, 'rest': 1, 'settler': 1, 'in': 2, 'there': 1, 'for': 2, 'the': 4, 'stove': 1, 'those': 1, 'this': 1, 'was': 1, 'all': 1, 'without': 1, 'men': 1, 'against': 1, 'among': 1, 'you': 1}

# %% [markdown]
# ## 4. Normalize the counts and turn them into probabilities.

# %%
from collections import defaultdict

def build_transition_matrix(word_pairs):
    # Create a dictionary to hold counts of word pairs
    counts = defaultdict(dict)

    # Count occurrences of word pairs
    for w1, w2 in word_pairs:
        if w2 not in counts[w1]:
            counts[w1][w2] = 0
        if w1 not in counts[w2]:
            counts[w2][w1] = 0
        counts[w1][w2] += 1
        counts[w2][w1] += 1

    # Normalize the counts to turn them into probabilities
    for w1 in counts:
        total_count = sum(counts[w1].values())
        for w2 in counts[w1]:
            counts[w1][w2] /= total_count

    return counts

#Test the function
trans_norm = build_transition_matrix(word_pairs)
print(trans_norm['whom'])
# Out:
# {'else': 0.013513513513513514, 'i': 0.12162162162162163, 'him': 0.013513513513513514, 'it': 0.06756756756756757, 'race': 0.013513513513513514, 'we': 0.06756756756756757, 'with': 0.08108108108108109, 'he': 0.04054054054054054, 'people': 0.013513513513513514, 'they': 0.04054054054054054, 'booby': 0.013513513513513514, 'to': 0.06756756756756757, 'heroes': 0.013513513513513514, 'as': 0.013513513513513514, 'man': 0.02702702702702703, 'of': 0.04054054054054054, 'by': 0.013513513513513514, 'workman': 0.013513513513513514, 'friend': 0.013513513513513514, 'having': 0.013513513513513514, 'pauper': 0.013513513513513514, 'rest': 0.013513513513513514, 'settler': 0.013513513513513514, 'in': 0.02702702702702703, 'there': 0.013513513513513514, 'for': 0.02702702702702703, 'the': 0.05405405405405406, 'stove': 0.013513513513513514, 'those': 0.013513513513513514, 'this': 0.013513513513513514, 'was': 0.013513513513513514, 'all': 0.013513513513513514, 'without': 0.013513513513513514, 'men': 0.013513513513513514, 'against': 0.013513513513513514, 'among': 0.013513513513513514, 'you': 0.013513513513513514}

# %% [markdown]
# ## 5. Generate text based on this transition matrix

# %%
import random
#Pick word at random
chosen_word = random.choice(list(trans_norm.keys()))
text = chosen_word.capitalize() + " "
print("Here is my story:\n")
sentence_count = 0
word_count = 1
is_first_word = False
while sentence_count < 100:
    distribution = trans_norm[chosen_word]
    pop = list(distribution.keys())
    weights = list(distribution.values())
    
    next_word = random.choices(pop, weights=weights)[0]
    
    #Start a new sentence if the word PERIOD is picked
    if(next_word == "PERIOD"):
        text = text.rstrip()
        text += ".\n\n"
        sentence_count +=1
        is_first_word = True
        #Pick new random word to start next sentence
        next_word = random.choice(list(trans_norm.keys()))
        word_count = 0
    else:
        word_count += 1
        if is_first_word:
            text += next_word.capitalize() +  " "
            is_first_word = False
        else:
            text += next_word + " " 
    
    #If the sentences is 10 words long, you can just break it and add a new line
    #From the instructions, I understood that 10 is not necessarily the max sentence length
    #But just starting new line for aesthetic purposes (less cluttered)
    if (word_count == 10):
        text += "\n"
        word_count = 0
        
    chosen_word = next_word

print(text)
# Out:
# Here is my story:
#
# 7th the what bold enough near very the skin the
# or displaying after not will be to solve some pond
# the like i heard i dug had time no play
# any purpose their squeeze their goings and cold weather so
# many years after march of it is alone swamp and
# silver fetters icy an take refuge took his of object
# what sort what in do not does he whether it
# plough to compelled me that boast that so be collected
# to prepare) to be to what southern our liber our
# that harvest now is which buffalo which he world at
# its by wall-sides by mercenary greeks! where few laws grandest
# laws own serene in the of expense to enough will
# vary more of mortification the year which will be ever
# for simply in our father eighty to hold got twelve
# quarts two or noise the in the in the for
# she is indeed i have got had have been have
# i made and i could he spoke as country our
# is this to the as them hoed i never spoke
# who would leave his education an make to village garden.
#
# As be calked be first.
#
# Land the earth offered he had crossed the surface its
# or rather than thinner and beaches sand dams with things
# these are race a in whether water with procession in
# every succeeding numerous respect remaining ice the behold it of
# man.
#
# Into these three or irishmen before carefully mortised carefully is
# person do _they_ whether it that never baited were breaking
# up borne up came in august when and a _leuciscus_
# a with yellow its own my character well-like character the
# for those which he as evil doing be liberal studies
# the which lay may not did not work to buy
# to helped be determined are a to subject indians in
# the circling with barks of pygmies of spending on employment
# that dry docks dry that be may and removed have
# they were performances and the that was i do they
# commonly sufficient number the of heat vital vigor inexhaustible vigor
# its door at wondered that my in any where shore
# and buttermilk! and buried in investments succeeding investments succeeding investments
# in farm-houses in wine in three-o’-clock in which forest of
# their vocation who nutting and circumstances is of the in
# tempest in distressed nor method no name the other.
#
# Their semi-cylindrical form which field huckleberry a hunter departed a
# cheerful evening travelling in it.
#
# All her young two and door my crossing or week
# a rope or drink a with studying with noticed commonly
# a strange to conjure to up and was snow the
# ground rent which mode of history of officer asks “what’s
# asks me she was brave and track by the firmament
# with associated with ever was doors trap set forth come
# had i that it will he will they and appear
# will you would dive here in a or without do
# without and purity.
#
# For me the old in life the wind by course
# his fires hotter and rome and laughed he had he
# got to rules of a is seen have we may
# live—that is done has wandered always had not be may
# imagine may see one at detained and stubborn and paris
# through the in ground and they are you compel a
# violent a ” poetry no resting-place without again bathed having
# enjoyed i went i assure my in a to withdraw
# may malefactors may whatever on down its stars at once
# at than they while his skin his by their still
# keep yourself spend to serve the perhaps you split makes
# a you for who have i ice.
#
# Such as even as blunder a stove a stern and
# rice was the but apparently without and the ground and
# consciously not aware was homer and stillness while org/donate section
# 4 section org/donate section vertical a bad go should be
# boarded here may grow up from which held was going
# by vale to town the franklin the wooded a have
# most important.
#
# Some pitch-pine the only you are cooked and its character
# the meadow a compact flock a shore” a long journey
# such a boy to the save much fished actually but
# trade i that understand read them of side of the
# sunny afternoons—for i stamped they as far as me of
# oscillation of more much how much used to condemned is
# not trouble we can make our to merely what but
# the laborer’s the whistle their by the with a not
# be virtuous one all and roof may be true of
# the old brick a world but lonely more my hoe
# not does scrutiny does state a hundred and a house
# my of the river the knowledge my life commonly it.
#
# So be may not had it being _forced_ being less
# and hunger the painter knows nature.
#
# And thick foot a with the from indirectly related i
# day half for found he worked there.
#
# The to known hardly could he began with the state’s
# the whippoorwill the and large very near weather cold gray
# oaks hickories and things and felt and joy the beyond
# surface of the and hue and darkness till soldering till
# whistle of men which surface turning and suspect should i
# live honestly they now to any thing one who companion.
#
# Be only perhaps it that it comes out a crack
# a more heat and chase the by reading little a
# stony shores the scenery the when they if the streets
# of the misconception of the slavery little rice but superfluous
# a such a of our outside garment of town the
# connect which tent a to trace left no inventions are
# great my carpet my gun my view with pit-fashion with
# the for fuel no that reproach a has little difference
# much so but eye himself treat to their in last
# arrival last.
#
# Generally seemed full in bog-holes and read but makes which
# they that we do.
#
# And to forward and thermometer and temperance or at that
# chanced to directed brandy directed toward conduct my near so
# waters so shutting so excuse himself at the of consequence
# the north-east driving when times before you it if i
# found to be should be to thy skirts the desk
# my with mould itself mould easily be to see and
# living and went still is not wish it that of
# summer the beneath but condition one house and sleep to
# takes to wash back and graceful length ride at length
# at smelled at length prevail through the greek or four
# inches four inches thick for do not thus waves thus
# entertain an at first at baskets it on fell breadth
# and position and from what inquire homesteads these yet to
# belong to wading pickerel catch him or country new a
# at waterloo at least at the insects all his hammer.
#
# Either was which of fame won fame won fame than
# erect than when the farm work here work any epaulet
# i shall i knew all them at a passing through
# the with but _ let should resist.
#
# Or the case it is trade in some race the
# it all of comfort love and wood the enhanced the
# logic of the to fall like be not desperate answer
# such were time kill would even is scream of convenience
# as manly not thus find perhaps i sometimes to so
# purpose this heap this on us to me.
#
# The outset the increase of many than ornithology studying of
# undulation of woodpeckers on the at politicians of that corporations
# that was yesterday to-day start now the butt-end the weather
# warmest of the as if as many waste to way
# two at least get to a were a certain indistinct
# line was— line unobscured by going on fell comrades avoided
# it not do not know that she was cottage every
# where cellar some more but off mile in mid-summer being
# concealed behind.
#
# A house all the on it procuring in my own
# weight their loins their animate still its by this time
# from far hunt far ring sounding winter quarters all the
# pure walden pond for somewhere track-repairer somewhere find i seemed
# they have to history whose worth is charge no other
# cause of the of any other motive other millions are
# not corresponding a like a such was withdrawing was one
# but a winter when apart and gone all its pleadings
# its before years few feet five dishes the tresses of
# the culture _human_ culture concord trader among the admire the
# trace the drowning the year a potter a few a
# worse in the chips now that find when form soot.
#
# With playing with greenish ice pickerel one of a liberal
# be an is it if there was the when and
# themselves betray too was the water drinking water the power
# in but what to sunshine cheap the and run “amok”
# run and abstinence and road the mean to not were
# virtues of the in what is the of one of
# their of think that it harpy-like—so it and sonorously and
# hear some think that man an ox or cheated never
# distinctly inform distinctly himself t’other himself off left sometimes over-head
# walls of voice i left wheelbarrow to face hopeful face
# which sympathy which the next the and tortoises and pick
# an inward and roman wormwood roman wormwood—that’s roman made i
# said to appreciate and delay notwithstanding much problem the spring
# and cow disconsolate some would it that and him in
# such safe are rabbit and cold and think honestly we
# which referred have and position of part.
#
# My from me.
#
# My house a half walked ever i drove i should
# earn ten or failed we stay at which conflagrations great
# waste and nearer than more no fellow-townsmen no need we
# while all the esquimaux the midst of string of warranties
# or are we as information me that i sometimes by
# woods when estate an elderly an eighth an established an
# influx an of evergreen or greek poet a hole a
# within him buy greedily but alert in town with troubled
# be to sometimes friends their with my estimation for excepting
# our concord village the wind the most the hope the
# of flakes with it restore mankind.
#
# The truth much thinner much so much more emphasis or
# azad or beans for the to an of only women
# and woodchucks hunting—pigeons woodchucks for subject.
#
# In my auxiliaries my townsmen there is the of peace
# and frosts might live as far from those states are
# which brakes and myself by the of advantage is patriotism
# of the wood-thrush long on this institution and pumpkins of
# cock-crowing of the through them in point of condition of
# the with world the influence an about evening and in
# such with the shore the fashions other tools the of
# day and spring sun the as it would some contain
# "defects" contain one only realities he would not thus also
# meanwhile returned meanwhile else.
#
# Who farmer a house my to enabled to a body
# whole the to stones precious with them perceive not.
#
# Attempt to hire all the shanty collins’ james had this
# is he had dried had time time of parts in
# its up in resting on almost as operate as might
# i could i and bells rung bells the wolf and
# shelf the and window on exhibition theatrical a or country
# stopping no was gone have drained have could do we
# have may least that all souls congenial to confined to
# better by appeared to intervals long period unlimited by cheered
# continually putting just by some may he ideas he is
# it misfortune.
#
# A to rise which is faith—i am i but perchance
# which through the in in that hear the vapor thin
# three pups three or distribute it.
#
# To ought.
#
# Of smoothness of some of warmth the of it is
# once or tree to thinking was thinking or stuff waste
# great consumer of our to not is parlor village the
# first to work for their streets village.
#
# Waving johnswort mulleins johnswort and studs or tea herb tea
# with wide as trespassers as if they become mediocrity in
# water.
#
# Their useless them.
#
# And more heat of the at also i nor poverty
# my acquaintances my experience new york and hole to bring
# two feet my of pleasure this danger in late and
# run and his axe not to them so sincerely are
# you share my “cultivator” my fed they were a heart-leaf
# which fall the from me made it to an of
# flapping great only and me again run over walked i
# drank and spend to keep his in life poor students
# or suppressed or not was barn seventy-five feet my beans
# to experience we for some colored and tracks deep feet
# my arguments and welcomed and long there.
#
# A that in the of the where perch as goose
# stray some this height for fowling a making are who
# are all.
#
# Flitting hither flitting reed-birds the in were as the greek
# poet has waded about sets about it as i where
# also at in but _dry land_.
#
# Low moaning low shrubs of shavings would potatoes for two
# knives our temporal necessities even are seeds which through to
# the intercourse might still his fenda dwelt now prey on
# their through passes over and wind blew wind or even
# not rejoice and deep bays its of one for death
# everlasting an of loaf a or do nothing was he
# after march 1845 my under the to me pleases it.
#
# Imperfect are they are few weeks six rods of better
# men honest some which was this purpose of cooked of
# thrill of a covering a or rabbit the factitious all
# of lowing of replacement a particular written rude though this
# head your with their eyes if life.
#
# A considerable extent is true little this and such is
# where land the shutter the why more to catch could
# he that remember i kept any at and surface.
#
# That confess that time directly more terrible certain minstrels by
# even him.
#
# Many by produced by a by amused myself ranging theirs
# like more of rid get a cannon ball cannon a
# or snow of things at a acres eleven o’clock at
# pure indian provinces indian went rolling harrowing rolling went i
# began with his has had i when we lived had
# done be put they will he was removed have i
# ought i if occasions if you as regarded mountains to
# religion and a cable a liquor to calculate to try
# these for it and blood how see us with rat
# with bark the april of abundance the stream the for
# foundation archive foundation are lines diverging lines through it so
# off by up got set trap.
#
# Tu-who of entirely of experience.
#
# But manure the in again.
#
# The and to the swamp-pink the red-wing and cider and
# stubborn and alert in the treating with a dingy a
# wedge a robin for am i love i could not
# corresponding not to love to be to or a seizes
# and story how remember i took it that thought we
# when its up before a trophy seeking mornings summer and
# belfry the to take refuge the of had which i
# as long with my past of advantages of invisible an
# half lying by it was i while i stumps like
# fragrant like the bell i have some bright flame.
#
# With a bright and sides the with full pursuit of
# abstract of principles the over off their sticks the water’s
# edge on the but though day he when river the
# plant corn the markets the melting apace melting the on
# trees level cannot probably will.
#
# An inoffensive an officer the are you derive servant come
# very low and furniture our but faults is soft ripples
# its lofty and here insist to act own who like
# that thought to do not a child and rude occupants
# rude substantial many have done have i am i should
# give it to corresponding with nights by which i that
# and hazel-bushes and impossible soon recovered own but summer like
# or shiner or expense pecuniary merely but dale but taking
# place giving to market.
#
# Chamber council his dismiss his to evening the right the
# have i came to as well has been not us
# thrills and hammer and outlet except would which this luxuriant
# foliage or ten times daily almost uninterruptedly almost any whether
# they had i since little a peck a height in
# is.
#
# Who us nearer now reviews now but war of hardest
# woods.
#
# Times twenty than usual capital using and hand-mill and night
# at pecked at his in would they them on them
# or a like a in some by skirts as thoughts
# your at they had the age and though beans and
# genius or last at leaves of a casual observer would
# have i remember thy but it has editor whose worth
# was sharply was man the 3.
#
# The garden herb ancient the sandy the melt your life
# near at of beasts to my for other is it
# convinces it is country native town the usual course to
# inaudible harmony far so are as slumbering been have forged
# have been represented on down its complete to speak next
# the life of their advantages—it must stores what he even
# from me to speak understandingly on the use would america
# and he breathes it know not in new every sense
# a with crust insulated and day in pond and brutish
# nature puts which apple which at look at when years
# late too farm at highest who told me much so
# have i believe is which has never seen have i
# whom of a fragrance like other one and day hazy
# brush—this the feel moment a take miracle a well that
# i while i as i declined i encountered some of
# systems for he farthest are things these had never field
# _his_ only the with included license gutenberg-tm.
#
# Which those like only the martins the civilized and that
# to the during the auction and clothing more comfortable a
# charge no man but none is not want will state
# and eat and members own its public ports in my
# of the and deeds heroic books buy them for as
# contentedly as are determined and they sometimes i grieved with
# go out let to re-create his head my so i
# turned it carry to keep will of that of virtue
# and throats.
#
# Of opening the upon.
#
# Deep and to while the find can stand in such
# expediency and sun not only was informed yourself than methods
# what he had nourished had he was a family mansion
# family.
#
# Of—we spoken of is admiring is he didn’t he that
# of prospect of tastes but as called whirlpool and skilled
# in testament the sins their regularity the utmost the sea-coast
# also where bottom but being burned.
#
# I discovered and mind the for eight or replacement or
# fall or one mouth his in the of way across
# the blindly and serious things the imperfection of society to
# which seeds are riding but judge to while he disregards
# and it is offer is which wildness which scenes wanted
# to belong to wounds fatal without seeing of men educated
# never stables sheepcots stables sheepcots hills which yielded had and
# had squirrel a project gutenberg-tm electronic works the without do
# with found not agree climates where he cannot recognize cannot
# you through to avenge to it grew glabra_) and third
# a long is birds the midst the from the traveller
# the years some professor where they have rarely had a
# only read true has civilization is true integrity day other
# many points of the same the study a was at
# him without tight and smoked and still ” sometimes also
# told and practical all animal indigenous animal without woods the
# soul trail her retain would man had of dirt the
# upper the green.
#
# When at the in the scares the foundation was sometimes
# ponds so much faster there a occasionally lit up taken
# had of their store goods holding were safety were many
# how and hues all the so fair to adapted to
# improve so world.
#
# Made jelly made at my fellow-citizens were a like a
# in them for secure a foot and medium a of
# cent of 27th the till phenomena the called are lucky
# fox and road-side the on and he shores then should
# master of third his death and nests and companion its
# near river concord bell the reflection the shore but richer
# say almost the scented the moisture and cowhide boots..
#
# The chips the house the back and fires but suddenly
# sank suddenly stop do—not village in falling from the town
# the view of taxation of indies the and stone a
# greater extent considerable height the woods which chips the ages
# of degrees its bays of ” he had probably fishes
# in front only a different beings.
#
# And green eating was in november colors brown paper for
# as marked is it.
#
# He gun my frugal my for respect as well _
# see not remarkably smooth is truth the round sat on
# or drawing morning since multiplied greatly not were they who
# instinctively who have appeared! have who fail to once effectually
# so fluctuating so conducted well thought they cheer and perch
# small left slavery where stones throwing the charming the south
# hill-side south of conscious of suicide of my to learn
# only yielded only the least disposition to allow—would it put
# to enough long mile a from settling of all and
# hang to trust in bark the reader will be would
# he if their bodies celestial the yields to get all
# times and without two over the leaven about the while
# for overhead for pond and deucalion that care take to
# it and heard a such many as does not it
# grows it that they have heard i could how often
# flat gray vermont gray and adventures their graves unmarked the
# mists through the nearest neighbor yesterday and by opening the
# and corners and i if its chaps under spot which
# skim which house actually not were things enough the external
# senses.
#
# From separated and hence and shore stony the horizon..
#
# Best the and defence awaiting their up and oil 40¾
# oil a on all for complaint having 1850 24th february
# 24th 1850 24th february night or the tresses the ice
# the life into fell in the darkening and they shells
# they got up in forgotten.
#
# Furniture warehouse.
#
# Location breed’s location on pushing life or succeeded by two
# way to society the insect an many a boat a
# or history the with her passed castles in siberia in
# interest in jail the man one who one sunny the
# engine your and refined as i looked he that he
# for taste for fear need only proportionally more or fall
# before wood-pile or them as far get our lincoln and
# free-trade and scented which he as such as most the
# right or return to relation same the enjoyed they are
# not discovered that misery are rail-fences are they seem as
# that since contented serene to time made in winged in
# books read been particularly have always and you may mind
# your very admirable in peeping of any that was covered
# once fellows the out lay his misfortune his memory the
# presence mere provender.
#
# Beyond enough we lived brister which my with synonymous is
# it which scotland in some curious the of despair of
# timid or from a convenient places such a dinner a
# for way this pond and preserve to gone and bear
# some at once for they be to the of their
# of only taught the by woods the is said been
# prevented many so got have call world by out at
# of dreamed it for enough exaggerate cannot go all round
# and pasture was it is itself is it fringe of
# men most simple expediency of grounds and not and waves
# that he came there but it until i was not
# merely not and reserved a for works celebrated works gutenberg-tm
# electronic works electronic works not has not only been made
# that they are they intentions their in questions such a
# white-pine a with every not is it at the afternoon
# in magnus in melts first the next the were not
# if a for taste that you tell neighbors my of
# the everlasting the iron and this would men love i
# morning.
#
# As developed as much sober keep and he wakes he
# may we sure not to began to paley to enjoy
# would be and pond of the in would philosophers ancient
# and the village the bank and at least the through
# the from the country’s the winter..
#
# Of life.
#
# He last which pond at meet will nibble to know
# men to access to be may get could and familiar
# quite are and wooden than colder than listen with the
# counting the round and probably and employees are hands or
# bark of muskrats of the long a man no time
# same tenure that this experience but if they not that
# so contained township the to make life bravely after stick
# too going their over the price for where in summer
# in deliberation to yield of protection its in the on
# which with rapid or italy or two casks so and
# to not consciously devised consciously and hue the dimpling and
# day as carefully before the when the satisfy the conversation
# and presence of nothing yet but politics or a-fishing here
# in classics ancient sect ancient however the terms different colors
# at a being may lay it may admire to undertook
# who own account circumstantial very a shouldered contemporaries my townsman
# my are they constitute a carried alexander only one answers
# obediently and is it turn that “the that care only
# sighed only it doing that.
#
# Of his in early up turned my are ebooks unless
# this though and not holy teacher holy the world this
# advantage their of tobacco is and we may discover die
# or cow which was it is remote truth to board
# the but know that it that the great this with
# water sacred laws the for food this glorious creation where
# it on depend and yard front adversary’s front line the
# future that class than listen with axe old axe and
# then.
#
# And in months two feet long and song and headlands
# and substance of man a got soon pretty game of
# rules special nothing absolutely is suited admirably sound wildest the
# majority it though and hunt i doubt almost how wonder
# to according is earned to sides to partially the nature
# would exercise intellectual are we could not are auxiliaries my
# paddled having taken were hills are sticks few warm them
# divert them transgress we he remember one be to oversee
# to detect encircling detect may be accounted be transported thither
# woods.
#
# Who two quarts two or hungry and dale and up
# take life shall never they for deep unusually squeamish not
# the over about nothing is not was sun the ears
# of laws sacred art.
#
# Over my window cottage architecture! cottage every reflected be may
# rise generously rise would even then that there were latest
# the when i should not cornice not in the in
# days summer in books though but faults his cook and
# animals other and experience in inches deep feet.
#
# And ever.
#
# Without veils without fear i and west the shore made
# been has it no of heroes whom the into the
# over stands resounded with dripping confluent dripping of my house
# ring house a chiefly but theoretically only not are names
# true the for all sunk my with sport better being
# from the view my hoe quite was woodchuck skin the
# greet them individualize to suffer the roof one cup a
# civilization is liable be not ebooks gutenberg-tm project gutenberg project
# gutenberg-tm project a of culture intellectual other the woods oak
# leaves of a came there mid-day there summer first i
# behold who loves to near dwell.
#
# Save property as be good a very thing best their
# lives he was cousin the of talk not have men
# again be in faith making it is the weary like
# manner they as such kindredship is there sit at the
# result the blue berries make can it is but force
# what was it be connected be to one is the
# to mean i summer a have never got most the
# days in itself unimpaired itself and grapes sour not do
# i had they take up and i could readily ascend
# readily ascend the house own account both goods—though both scrape
# would you if and distribute copies all around formed had
# he thoroughly believed they stood he that basis be vain
# in the world and be a good boards “good sweet
# and defence similar reason no had perchance to sure not
# will appear alike rays sun’s hazy sun’s the this small
# and warm too been bought at a under a with
# the precisely in weak relic weak joints and wall the
# largest houses splendid build may have might have stood up
# from the choicest of the length on.
#
# Originally were grounds were that is it is who he
# would not are they are.
#
# Pinions he wonders he would feel compassion restrained compassion moment
# present at hungry or wit called is an derived are
# dinning in a robber a to my after great the
# families and content doing our as again path i how
# shall get and hosmer.
#
# Than on spots black one farmer new-england farmer a hard
# rain with age was ready seeds the as a like
# a half one fronting right his way the bison of
# sense by which it ” so why did.
#
# And muddy and ladies the hooting owl the ground the
# meaning of linen to their will stretch itself impaling itself
# skin the real a small loaves small pond the night
# and door his skin which experience in quarters of temperament
# even things of eighth an though i cannot survive so
# i formerly that when hills highest the than raisers his
# orchards—raise his name specific receive can pass to it is
# like grandly went indian than thirty miles two for not
# our dullest perception principle—the from up together in which the
# opportunity to a fresh minute a like precious to not
# like lava sometimes one and distantly hand on companion on
# knees and costs anything be to the of charge anything
# practically speak cannot come with fuel of manners were hens
# were wages for freedom’s for shingles refuse state—and refuse to
# be to a poet a higher spiring higher but head
# its fogs and man of surface its crimpled its foot
# deeper fish they are we call who readers my see
# _ see what occupies exactly tell which was only walden
# woods—cato walden at sigh at first shelter a ages heroic
# and best which entertain to rule a resurrection and he
# fears he trees and a of life a it whether
# this great cakes the paying without constructed men most are
# there.
#
# And thick like a birch a considerable effort and all
# the through break could multitude could you or other geological
# other horizon is it if as that the hang the
# serving past walked he began i but he had i
# have you any) you crop small perch small in such
# an annual visitation which my among the crumbs at length
# at was never have who towns stitch a house my
# own to came to experiment of the uplands even rats
# in agitated and painters and wind.
#
# Tempted sometimes serenaded moonlight.
#
# Astronomers forever we if we say is it for feel
# longer no if there to a fox then and dark
# was there are all the middle the vishnu and commenced
# at the advantage this pond in such in such as
# wear or one end an to vain in money you
# if as thoughts better the reality is a fire-engine at
# but hearing by clarified its winged cat a dirt chip.
#
# He mercies he should not should file single dollar one
# but experience that find myself well as be may be
# to impart to exclude the road.
#
# But him pitied it over haste in name from the
# whole the thin partition common than obtained be to the
# to obedience blind that are majority rule of tears in
# rivet another more somewhat like the many _men_ being without
# feathers—and without avenues and shore stony a and time..
#
# Had as good subject.
#
# To cambridge every that i though and feet are rills
# are seeds if however _i_ or rather or climb or
# in the implements small a be to concluded he questions
# that remember it of heaven bearers heaven over the day
# every day comes frost a get out in accumulating in
# rocks and the stream the thoughtless the light the annual
# an insect an extent and the beneath hollow a of
# what calls anxious to wont.
#
# Myself in this purpose my reaches there never are you
# without it if there can follow westward follow cannot i
# when you more than that loud as horses as the
# government state a great deal to familiar very the remove
# the at in the when i could be the and
# went who hath antiquity of ice was part tenth a
# stop the among trader concord in her young and it
# trade but rivers in the that i festoons in engaged
# in scarecrow in as in nine and over the same
# the in thus do will both of liberty are few
# amusements because it can you could not is remarkable for
# several were hickories and winged either by watching or done
# for men.
#
# To distend their lot new the lowest grades lowest the
# there stayed i had not long a willow and i
# will bolts will boyhood of a few auger holes old
# and places many so with dotted with interferes with right
# my shed blood to helped so good will one day
# every cove was covered deep—not to the result of straw
# of life civilized of forms the in maggot a broad
# open air both and bulrush of quantity of the darkest
# the nuts may be to nothing had i chanced it
# almost leaves and dry life that of amusements of office
# to dollars cowhide dollars.
#
# Own experience rare so i went off and beholding leaf
# for hen-harriers for it chuckle a seat of heroic deeds
# heroic reader more or one and ottomans and calculation.
#
# Is individual project the front-yard gate my past half heaps
# the worlds of possession it leave.
#
# Or flying-squirrel or roots are so my paid the of
# selection of denial practical and his chose his hammer a
# of midst the market who fellow capital little is strewn
# with a counter friction the gone often i could i
# looked between us between that cooks that has no doubt
# almost the clouds by aspire or thaw them up on
# prisoner and rotten though i which i did so noble
# and conversation began he state the in where the most
# of our horizon.
#
# Of evidences of ice the over get _talaria_ get not
# of warranties other the most the against are dinning in
# duration days’ duration days’ duration days’ duration days’ duration days’
# duration days’ several and with angry with less still more
# yet written noblest the discovered a of nature will never
# should live for pay for sciences and hand-mill and scorched
# the nor conduct and warm after the terms other borrowed
# other nameless by their of “plump” of pain enduring is
# equivalent to direction of my to frankincense to the as
# will the end west my carpet whose cottage of ants
# of fountain-head the project gutenberg-tm project of paragraphs 1.
#
# And pressed and indian wigwams their schools i that me
# deliver me that direction to complain to my to owing
# where verses complemental verses of lapse the touches it that
# supposed he got the choice of right a choose i
# have designs one approaches one or life deluded be more
# favored more far pond the longest birch or north star
# morning in nothing memorable events memorable a note of principle
# being dirt of the on chip dirt chip dirt being
# concealed between and cart and solitary a if i have
# failed never missed never they are you..
#
# Boards and nothing know not see to woods having severed
# having his at until or encumbrances the is he showed
# me.
#
# Naturally and cell loath’d thy because we must be to
# offices the latter raises them there was middle ages.
#
# Cerealian in many so soft snow the right and gauging
# of article of existence as such acquired i should they
# may be doing so being a making a into the
# saddens nor lampreys nor did not only is the like
# a got sometimes i went and the of their fix
# to date was least oppressed least have i was to
# according to select the hollow the but often needs were
# driven were they take place giving “after they have supplied
# the still fewer came i light the of wildness—to wade
# wildness—to of expediency.
#
# Some anxiety from infancy but in mirage in caves suitable
# than the utter the of mine to nothing was a
# entertain which nimbly threaded the lakes eighty years ago long
# a thick a quarter a house until downward over skim
# to see in a modern taste of judge may they
# up go least that in us let alive are not
# a general the spring a suppose most part of or
# providing a in succession of bark tied way the original
# the warmest and how see to were all dells all
# that no is pursued with nature.
